# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import yfinance as yf
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import ollama  # LLaMA model API
import re
from tqdm import tqdm  # For progress bars
from concurrent.futures import ThreadPoolExecutor, as_completed  # For parallel processing
from gnews import GNews  # Import the GNews package
from pytz import UTC

# %% [markdown]
# ### Downloading historic asset price from yfinance

# %%
# Fetch Historical Prices
def fetch_all_historical_prices(asset_symbol, start_date, end_date):
    try:
        data = yf.download(
            asset_symbol,
            start=start_date.strftime('%Y-%m-%d'),
            end=end_date.strftime('%Y-%m-%d'),
            progress=False
        )
        if data.empty:
            raise ValueError(f"No data found for {asset_symbol} between {start_date} and {end_date}.")
        data = data[['Close']].rename(columns={'Close': asset_symbol})
        data.columns = [asset_symbol]
        return data
    except Exception as e:
        print(f"Error fetching data for {asset_symbol}: {e}")
        return pd.DataFrame()

# %% [markdown]
# ### Downloading historic asset news from Gnews

# %%
# Fetch News using GNews
def fetch_all_google_news(query, start_date, end_date):
    gnews = GNews(language='en', country='US', max_results=5)  # Limit to top 5 headlines
    all_news_list = []

    # Generate date ranges
    date_ranges = pd.date_range(start_date, end_date, freq='D')

    for date in tqdm(date_ranges, desc="Fetching news data"):
        date_str = date.strftime('%Y-%m-%d')
        try:
            # Fetch articles for the specific date
            articles = gnews.get_news(f"{query} after:{date_str} before:{(date + timedelta(days=1)).strftime('%Y-%m-%d')}")
            if articles:
                unique_titles = [article.get('title', 'No Title') for article in articles[:5]]  # Top 5 headlines
                news_content = " ".join(unique_titles)
                news_content = news_content[:500]  # Limit news content to 500 characters
                all_news_list.append({
                    "Date": date,
                    "News": news_content
                })
        except Exception as e:
            print(f"Error fetching news for {date_str}: {e}")

    # Create DataFrame from the list
    all_news = pd.DataFrame(all_news_list)
    all_news.drop_duplicates(subset=["Date"], inplace=True)
    all_news.set_index('Date', inplace=True)
    return all_news

# %% [markdown]
# ### Load data locally or Fetch Data from yfinance & Gnews

# %%
# Load or Fetch Data
def load_or_fetch_data(asset_symbol, query, start_date, end_date, get_news=True):
    # Fetch or load historical prices
    if not os.path.exists(f"{asset_symbol}_historical_prices.csv"):
        print("Fetching historical prices...")
        historical_prices = fetch_all_historical_prices(asset_symbol, start_date, end_date)
        historical_prices.to_csv(f"{asset_symbol}_historical_prices.csv", index=True)
        print(f"Historical prices saved to '{asset_symbol}_historical_prices.csv'.")
    else:
        print("Loading existing historical prices...")
        historical_prices = pd.read_csv(
            f"{asset_symbol}_historical_prices.csv",
            parse_dates=["Date"],
            index_col="Date"
        )

        # Ensure the correct column name
        if asset_symbol not in historical_prices.columns:
            raise ValueError(f"The expected column '{asset_symbol}' was not found in '{asset_symbol}_historical_prices.csv'.")

        historical_prices = historical_prices[[asset_symbol]]  # Select the column for the asset

    if get_news==True:
        # Fetch or load news data
        if not os.path.exists(f"{asset_symbol}_news_data.csv"):
            print("Fetching news data...")
            news_data = fetch_all_google_news(query, start_date, end_date)
            news_data.to_csv(f"{asset_symbol}_news_data.csv", index=True)
            print(f"News data saved to '{asset_symbol}_news_data.csv'.")
        else:
            print("Loading existing news data...")
            news_data = pd.read_csv(
                f"{asset_symbol}_news_data.csv",
                parse_dates=["Date"],
                index_col="Date"
            )
    else:
        news_data = None

    return historical_prices, news_data

# %%
# Get the date using index difference.
def LastMarketOpen_DateDiff(df, curr_date, delta):
    '''Index of the dataframe is pandas datetime format. In case date is a column in dataframe use timedelta toget the difference.'''
    curr_date_index = df.index.get_loc(curr_date)
    final_date = pd.to_datetime(df.iloc[curr_date_index+(delta)].name)
    return (final_date)

# %% [markdown]
# ### Given one slice of input data making n-simulated predictions.
# - Instead of taking past m days window size, here we will take past m indexes because some stock exchanges remain closed on holidays.
# - News data for each market open day should be the cummulation of all news which came after the last market day till the current day.

# %%
# Predict Next Day's Price with LLaMA (Probabilistic) including news
def predict_next_price_probabilistic(
    asset_symbol,
    current_date,
    historical_prices,
    news_data,
    window_size,
    n_simulations,
    quantiles=(0.05, 0.5, 0.95)
):

    # current_date_index = historical_prices.index.get_loc(current_date)
    # start_date = pd.to_datetime(historical_prices.iloc[current_date_index-(window_size - 1)].name)     # current_date - timedelta(days=window_size - 1)
    start_date = LastMarketOpen_DateDiff(historical_prices, current_date, -(window_size - 1))
    historical_window = historical_prices.loc[start_date:current_date].dropna().values.flatten()

    if len(historical_window) < window_size:
        print(f"Insufficient data for prediction on {current_date.date()}.")
        return None, None, None

    historical_prices_str = ", ".join(f"{x:.2f}" for x in historical_window)
    predictions = []

    # Get news data from the last market open date to current_date
    prev_hp_date = LastMarketOpen_DateDiff(historical_prices, current_date, -1)
    # curr_dt_index = news_data.index.get_loc(current_date)
    # prev_dt_index = news_data.index.get_loc(LastMarketOpen_DateDiff(historical_prices, current_date, -1))

    prompt = (
        f"Given this data:\n"
        f"Historical prices for {asset_symbol} over the past {window_size} days:\n"
        f"{historical_prices_str}\n"
        f"Based on the historical prices, predict the price for {asset_symbol} for the next day.\n"
        f"Provide your prediction as a single number (e.g., 38500). Do not include any text other than the number."
    )

    def run_simulation(_):
        try:
            response = ollama.chat(
                model="llama3.1",
                messages=[
                    {"role": "system", "content": "You are a financial forecasting assistant."},
                    {"role": "user", "content": prompt}
                ]
            )
            response_content = response["message"]["content"]
            match = re.search(r"[\$]?[0-9,]+\.?[0-9]*", response_content)
            if match:
                return float(match.group().replace(",", "").replace("$", ""))
        except Exception as e:
            print(f"LLaMA simulation failed: {e}")
        return None

    max_workers = min(10, n_simulations)  # Limit number of threads
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(run_simulation, _) for _ in range(n_simulations)]
        for future in tqdm(
            as_completed(futures),
            total=n_simulations,
            desc=f"Simulating {n_simulations} predictions for {current_date.date()}"
        ):
            result = future.result()
            if result is not None:
                predictions.append(result)

    if len(predictions) == 0:
        print(f"No valid predictions generated for {current_date}.")
        return None, None, None

    # Calculate quantiles
    quantile_values = np.quantile(predictions, quantiles)
    return quantile_values[0], quantile_values[1], quantile_values[2], predictions

# %% [markdown]
# ### Making predictions on a roling window from start_date to end_date

# %%
# Rolling Predictions with Probabilistic Forecasting including news
def rolling_window_price_predictions_probabilistic(
    asset_symbol,
    historical_prices,
    news_data,
    start_date,
    end_date,
    window_size,
    n_simulations
):
    historical_prices.index = pd.to_datetime(historical_prices.index).normalize().tz_localize(None)
    # news_data.index = pd.to_datetime(news_data.index).normalize()
    # Adjust start_date to ensure enough data for the window
    earliest_date = historical_prices.index[0 + window_size - 1]      #+ timedelta(days=window_size - 1)
    print(earliest_date)
    start_date = max(start_date, earliest_date)
    current_date = start_date
    end_date = min(end_date, historical_prices.index[-2])  # Ensure end_date is within available data  # - timedelta(days=1)

    predictions = []
    raw_prediction_list = []
    iteration = 0

    while current_date <= end_date:
        current_date_norm = pd.to_datetime(current_date).normalize()

        # Calculate the start date of the window
        # window_start_date = current_date_norm - timedelta(days=window_size - 1)
        window_start_date = LastMarketOpen_DateDiff(historical_prices, current_date_norm, -(window_size - 1))

        # Check if the window is within the data range
        if window_start_date < historical_prices.index[0]:
            print(f"Not enough historical data to create a window for {current_date_norm.date()}. Skipping.")
            # current_date += timedelta(days=1)
            current_date = LastMarketOpen_DateDiff(historical_prices, current_date, 1)
            continue

        low, median, high, raw_predictions = predict_next_price_probabilistic(
            asset_symbol,
            current_date_norm,
            historical_prices,
            news_data,
            window_size,
            n_simulations
        )

        # Get the actual price for the next day (the day after current_date)
        # next_date = current_date_norm + timedelta(days=1)
        next_date = LastMarketOpen_DateDiff(historical_prices, current_date_norm, 1)
        if next_date in historical_prices.index:
            actual_price = historical_prices.loc[next_date, asset_symbol]
        else:
            print(f"No actual price available for {next_date.date()}. Skipping.")
            current_date = LastMarketOpen_DateDiff(historical_prices, current_date, 1)
            continue

        # Cumulating raw predictions from all runs
        raw_prediction_list.append(raw_predictions)

        if median is not None:
            predictions.append(
                (next_date, low, median, high, actual_price)
            )
        else:
            print(f"No prediction available for {current_date_norm.date()}.")

        current_date = LastMarketOpen_DateDiff(historical_prices, current_date, 1)

        iteration += 1
        if iteration%30 == 0:
            predictions_df = pd.DataFrame(
                    predictions,
                    columns=["Date", "Low_Prediction", "Median_Prediction", "High_Prediction", "Actual_Price"]
                )
            predictions_df.to_csv('predictions_partial.csv', index=False)
            
            
            raw_output_df = pd.DataFrame(raw_prediction_list,
                                         columns = [f"out_{i}" for i in range(n_simulations)])
            raw_output_df["Date"] = predictions_df["Date"]
            raw_output_df.to_csv('raw_output_partial.csv', index=False)
                                         

    predictions_df = pd.DataFrame(
        predictions,
        columns=["Date", "Low_Prediction", "Median_Prediction", "High_Prediction", "Actual_Price"]
    )
    raw_output_df = pd.DataFrame(raw_prediction_list,
                                 columns = [f"out_{i}" for i in range(n_simulations)])
    raw_output_df["Date"] = predictions_df["Date"]
    
    return predictions_df, raw_output_df

# %% [markdown]
# ### Plotting real and predicted prices

# %%
# Plot Predictions and Metrics
def plot_predictions_and_compute_metrics_probabilistic(
    predictions_df,
    asset_symbol,
    save_path="predictions_chart.png"
):
    predictions_df = predictions_df.dropna(subset=["Median_Prediction", "Actual_Price"])
    actual_prices = predictions_df["Actual_Price"]
    median_predictions = predictions_df["Median_Prediction"]

    if predictions_df.empty or actual_prices.empty or median_predictions.empty:
        print("No predictions to plot or compute metrics.")
        return None, None

    rmse = np.sqrt(mean_squared_error(actual_prices, median_predictions))
    r2 = r2_score(actual_prices, median_predictions)

    plt.figure(figsize=(10, 6))
    plt.plot(
        predictions_df["Date"],
        actual_prices,
        label="Actual Prices",
        color="blue",
        linestyle='-'
    )
    plt.plot(
        predictions_df["Date"],
        median_predictions,
        label="Median Predictions",
        color="red",
        linestyle='--'
    )
    plt.fill_between(
        predictions_df["Date"],
        predictions_df["Low_Prediction"],
        predictions_df["High_Prediction"],
        color='gray',
        alpha=0.3,
        label="Prediction Range (1%-99%)"
    )
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.title("Probabilistic Forecasting: Predicted vs Actual Prices with News Influence")
    plt.legend()
    plt.grid(True)
    # plt.ylim([100,250])
    plt.xticks(rotation=45)
    plt.tight_layout()

    # Save the plot as a transparent PNG
    plt.savefig(save_path, transparent=True, dpi=300)
    print(f"Chart saved to {save_path} (transparent background).")

    plt.show()

    print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
    print(f"Out-of-Sample R2: {r2:.4f}")
    return rmse, r2

# %% [markdown]
# ### Execution
# #### Assumptions:
# - Complete data for all  market data is available from start_date to end_date

# %%
# assets = ['^GSPC', 'GOOG', 'XLE', '^STOXX', '^N225', '^BSESN', '^FTSE', 'TXGE', 'BTC-USD']
assets = ['GOOG']

# %%
# Main Execution
if __name__ == "__main__":
    for asset in assets:
        asset_symbol = asset
        query = None
        start_date = pd.to_datetime('2024-01-01')  # Adjusted to 2023 as future data may not be available
        end_date = pd.to_datetime('2024-11-30')
        print(start_date)
        print(end_date)
        window_size = 15
        n_simulations = 1000  # Adjust this value as needed
    
        # Import or Fetch Data
        historical_prices, news_data = load_or_fetch_data(asset_symbol, query, start_date, end_date, get_news=False)
    
        # Rolling Predictions with Probabilistic Forecasting
        predictions_df, raw_output = rolling_window_price_predictions_probabilistic(
            asset_symbol,
            historical_prices,
            news_data,
            start_date,
            end_date,
            window_size,
            n_simulations
        )
        
        predictions_df.to_csv(f'{asset_symbol}_predictions_full_no_news.csv')
        raw_output.to_csv(f'{asset_symbol}_raw_output_no_news.csv')
    
        # Plot and Evaluate Metrics
        rmse, r2 = plot_predictions_and_compute_metrics_probabilistic(predictions_df, asset_symbol, f"{asset_symbol}_predictions_chart_no_news.png")
    
        if rmse is not None and r2 is not None:
            print("\nFinal Metrics:")
            print(f"RMSE: {rmse:.4f}")
            print(f"R2 Score: {r2:.4f}")
# Out:
# 2024-01-01 00:00:00
# 2024-11-30 00:00:00
# Loading existing historical prices...
# 2024-01-23 00:00:00
# Given this data:
# Historical prices for GOOG over the past 15 days:
# 139.06, 139.86, 137.55, 136.90, 140.03, 142.05, 143.29, 143.16, 143.72, 143.56, 142.38, 144.47, 147.44, 147.18, 148.15
# Based on the historical prices, predict the price for GOOG for the next day.
# Provide your prediction as a single number (e.g., 38500). Do not include any text other than the number.
# Simulating 1000 predictions for 2024-01-23:   0%|      | 0/1000 [00:00<?, ?it/s]01/11/2025 11:29:30 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   0%| | 1/1000 [01:03<17:29:44, 63.001/11/2025 11:29:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   0%| | 2/1000 [01:03<7:19:21, 26.4101/11/2025 11:29:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:32 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   0%| | 5/1000 [01:04<2:08:46,  7.7601/11/2025 11:29:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   1%| | 6/1000 [01:05<1:39:25,  6.0001/11/2025 11:29:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   1%| | 9/1000 [01:06<49:59,  3.03s/01/11/2025 11:29:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   1%| | 10/1000 [01:07<44:16,  2.68s01/11/2025 11:29:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   1%| | 13/1000 [01:08<25:34,  1.55s01/11/2025 11:29:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   1%| | 14/1000 [01:09<24:47,  1.51s01/11/2025 11:29:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   2%| | 17/1000 [01:10<15:29,  1.06i01/11/2025 11:29:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   2%| | 18/1000 [01:11<16:24,  1.00s01/11/2025 11:29:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   2%| | 21/1000 [01:12<11:02,  1.48i01/11/2025 11:29:41 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:41 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   2%| | 22/1000 [01:13<12:40,  1.29i01/11/2025 11:29:41 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   2%| | 25/1000 [01:14<08:53,  1.83i01/11/2025 11:29:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   3%| | 26/1000 [01:15<10:45,  1.51i01/11/2025 11:29:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   3%| | 29/1000 [01:16<07:45,  2.08i01/11/2025 11:29:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   3%| | 30/1000 [01:17<09:52,  1.64i01/11/2025 11:29:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   3%| | 33/1000 [01:18<07:16,  2.22i01/11/2025 11:29:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   3%| | 34/1000 [01:19<09:23,  1.71i01/11/2025 11:29:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   4%| | 37/1000 [01:20<07:01,  2.29i01/11/2025 11:29:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   4%| | 38/1000 [01:21<09:06,  1.76i01/11/2025 11:29:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   4%| | 41/1000 [01:22<06:56,  2.30i01/11/2025 11:29:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   4%| | 42/1000 [01:23<09:13,  1.73i01/11/2025 11:29:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   4%| | 45/1000 [01:24<06:45,  2.36i01/11/2025 11:29:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   5%| | 46/1000 [01:25<09:20,  1.70i01/11/2025 11:29:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   5%| | 49/1000 [01:26<07:03,  2.25i01/11/2025 11:29:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   5%| | 50/1000 [01:27<09:09,  1.73i01/11/2025 11:29:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   5%| | 53/1000 [01:28<06:50,  2.31i01/11/2025 11:29:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   5%| | 54/1000 [01:29<09:08,  1.72i01/11/2025 11:29:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   6%| | 57/1000 [01:30<06:48,  2.31i01/11/2025 11:29:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   6%| | 58/1000 [01:31<09:03,  1.73i01/11/2025 11:29:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:29:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   6%| | 61/1000 [01:32<06:41,  2.34i01/11/2025 11:30:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   6%| | 62/1000 [01:33<08:45,  1.78i01/11/2025 11:30:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   6%| | 65/1000 [01:34<06:30,  2.39i01/11/2025 11:30:03 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:03 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   7%| | 66/1000 [01:35<08:41,  1.79i01/11/2025 11:30:03 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:03 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   7%| | 69/1000 [01:36<06:31,  2.38i01/11/2025 11:30:05 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:05 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   7%| | 70/1000 [01:37<08:58,  1.73i01/11/2025 11:30:05 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:05 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   7%| | 73/1000 [01:38<06:49,  2.26i01/11/2025 11:30:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   7%| | 74/1000 [01:39<09:11,  1.68i01/11/2025 11:30:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   8%| | 77/1000 [01:40<06:49,  2.26i01/11/2025 11:30:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   8%| | 78/1000 [01:41<08:59,  1.71i01/11/2025 11:30:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   8%| | 81/1000 [01:42<06:52,  2.23i01/11/2025 11:30:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   8%| | 82/1000 [01:43<09:30,  1.61i01/11/2025 11:30:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   8%| | 85/1000 [01:44<07:03,  2.16i01/11/2025 11:30:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   9%| | 86/1000 [01:45<09:04,  1.68i01/11/2025 11:30:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   9%| | 89/1000 [01:46<06:14,  2.43i01/11/2025 11:30:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   9%| | 90/1000 [01:48<09:39,  1.57i01/11/2025 11:30:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:16 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   9%| | 93/1000 [01:48<07:08,  2.12i01/11/2025 11:30:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:   9%| | 94/1000 [01:49<08:47,  1.72i01/11/2025 11:30:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  10%| | 97/1000 [01:51<07:27,  2.02i01/11/2025 11:30:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  10%| | 98/1000 [01:51<08:00,  1.88i01/11/2025 11:30:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:21 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:21 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  10%| | 101/1000 [01:53<08:06,  1.8501/11/2025 11:30:21 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:21 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  10%| | 104/1000 [01:54<06:25,  2.3201/11/2025 11:30:23 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:23 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  10%| | 105/1000 [01:55<08:14,  1.8101/11/2025 11:30:23 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  11%| | 108/1000 [01:56<07:41,  1.9301/11/2025 11:30:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  11%| | 109/1000 [01:57<08:25,  1.7601/11/2025 11:30:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  11%| | 112/1000 [01:59<08:42,  1.7001/11/2025 11:30:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  12%| | 115/1000 [02:00<06:53,  2.1401/11/2025 11:30:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  12%| | 116/1000 [02:01<08:53,  1.6601/11/2025 11:30:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:30 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  12%| | 119/1000 [02:03<08:07,  1.8101/11/2025 11:30:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  12%| | 120/1000 [02:03<08:48,  1.6701/11/2025 11:30:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  12%| | 123/1000 [02:05<08:58,  1.6301/11/2025 11:30:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  13%|▏| 126/1000 [02:06<06:57,  2.0901/11/2025 11:30:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  13%|▏| 127/1000 [02:07<08:43,  1.6701/11/2025 11:30:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  13%|▏| 130/1000 [02:09<07:32,  1.9201/11/2025 11:30:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  13%|▏| 131/1000 [02:09<08:04,  1.7901/11/2025 11:30:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  13%|▏| 134/1000 [02:11<07:55,  1.8201/11/2025 11:30:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  14%|▏| 137/1000 [02:12<06:08,  2.3401/11/2025 11:30:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  14%|▏| 138/1000 [02:13<07:43,  1.8601/11/2025 11:30:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:41 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  14%|▏| 141/1000 [02:14<06:43,  2.1301/11/2025 11:30:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  14%|▏| 142/1000 [02:14<07:10,  1.9901/11/2025 11:30:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  14%|▏| 145/1000 [02:16<07:12,  1.9801/11/2025 11:30:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  15%|▏| 148/1000 [02:17<05:39,  2.5101/11/2025 11:30:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  15%|▏| 149/1000 [02:18<07:05,  2.0001/11/2025 11:30:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  15%|▏| 152/1000 [02:19<06:16,  2.2501/11/2025 11:30:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  15%|▏| 153/1000 [02:20<06:53,  2.0501/11/2025 11:30:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  16%|▏| 156/1000 [02:21<07:24,  1.9001/11/2025 11:30:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  16%|▏| 159/1000 [02:22<06:02,  2.3201/11/2025 11:30:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  16%|▏| 160/1000 [02:23<07:53,  1.7701/11/2025 11:30:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  16%|▏| 163/1000 [02:25<07:05,  1.9701/11/2025 11:30:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  16%|▏| 164/1000 [02:25<07:44,  1.8001/11/2025 11:30:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  17%|▏| 167/1000 [02:27<07:44,  1.7901/11/2025 11:30:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  17%|▏| 170/1000 [02:28<06:05,  2.2701/11/2025 11:30:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  17%|▏| 171/1000 [02:29<07:43,  1.7901/11/2025 11:30:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  17%|▏| 174/1000 [02:30<06:55,  1.9901/11/2025 11:30:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:30:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  18%|▏| 175/1000 [02:31<07:26,  1.8501/11/2025 11:30:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  18%|▏| 178/1000 [02:33<07:34,  1.8101/11/2025 11:31:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  18%|▏| 181/1000 [02:34<06:00,  2.2701/11/2025 11:31:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  18%|▏| 182/1000 [02:35<07:31,  1.8101/11/2025 11:31:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  18%|▏| 185/1000 [02:36<06:35,  2.0601/11/2025 11:31:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  19%|▏| 186/1000 [02:37<07:08,  1.9001/11/2025 11:31:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  19%|▏| 189/1000 [02:38<07:08,  1.8901/11/2025 11:31:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  19%|▏| 192/1000 [02:39<05:40,  2.3801/11/2025 11:31:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  19%|▏| 193/1000 [02:40<06:59,  1.9201/11/2025 11:31:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  20%|▏| 196/1000 [02:41<06:07,  2.1901/11/2025 11:31:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  20%|▏| 197/1000 [02:42<06:39,  2.0101/11/2025 11:31:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  20%|▏| 200/1000 [02:43<06:45,  1.9701/11/2025 11:31:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  20%|▏| 203/1000 [02:44<05:18,  2.5001/11/2025 11:31:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  20%|▏| 204/1000 [02:45<06:44,  1.9701/11/2025 11:31:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:14 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  21%|▏| 207/1000 [02:46<06:02,  2.1901/11/2025 11:31:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  21%|▏| 208/1000 [02:47<06:31,  2.0201/11/2025 11:31:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:16 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:16 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  21%|▏| 211/1000 [02:49<06:45,  1.9501/11/2025 11:31:16 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  21%|▏| 214/1000 [02:49<05:23,  2.4301/11/2025 11:31:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  22%|▏| 215/1000 [02:50<06:49,  1.9201/11/2025 11:31:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  22%|▏| 218/1000 [02:52<06:08,  2.1201/11/2025 11:31:20 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:20 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  22%|▏| 219/1000 [02:52<06:40,  1.9501/11/2025 11:31:20 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  22%|▏| 222/1000 [02:54<06:50,  1.8901/11/2025 11:31:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  22%|▏| 225/1000 [02:55<05:25,  2.3801/11/2025 11:31:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  23%|▏| 226/1000 [02:56<06:57,  1.8601/11/2025 11:31:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  23%|▏| 229/1000 [02:57<06:14,  2.0601/11/2025 11:31:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:26 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  23%|▏| 230/1000 [02:58<06:43,  1.9101/11/2025 11:31:26 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  23%|▏| 233/1000 [02:59<06:45,  1.8901/11/2025 11:31:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:28 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  24%|▏| 236/1000 [03:00<05:17,  2.4101/11/2025 11:31:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  24%|▏| 237/1000 [03:01<06:43,  1.8901/11/2025 11:31:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:30 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  24%|▏| 240/1000 [03:02<05:52,  2.1601/11/2025 11:31:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  24%|▏| 241/1000 [03:03<06:19,  2.0001/11/2025 11:31:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:32 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:32 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  24%|▏| 244/1000 [03:05<06:28,  1.9501/11/2025 11:31:32 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  25%|▏| 247/1000 [03:05<05:08,  2.4401/11/2025 11:31:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  25%|▏| 248/1000 [03:07<06:32,  1.9101/11/2025 11:31:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  25%|▎| 251/1000 [03:08<05:50,  2.1401/11/2025 11:31:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  25%|▎| 252/1000 [03:08<06:25,  1.9401/11/2025 11:31:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  26%|▎| 255/1000 [03:10<06:39,  1.8701/11/2025 11:31:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  26%|▎| 258/1000 [03:11<05:14,  2.3601/11/2025 11:31:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  26%|▎| 259/1000 [03:12<06:41,  1.8401/11/2025 11:31:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:41 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  26%|▎| 262/1000 [03:13<05:58,  2.0601/11/2025 11:31:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  26%|▎| 263/1000 [03:14<06:29,  1.8901/11/2025 11:31:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  27%|▎| 266/1000 [03:16<06:37,  1.8501/11/2025 11:31:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  27%|▎| 268/1000 [03:16<05:18,  2.3001/11/2025 11:31:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  27%|▎| 270/1000 [03:18<06:36,  1.8401/11/2025 11:31:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  27%|▎| 273/1000 [03:18<05:05,  2.3801/11/2025 11:31:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  27%|▎| 274/1000 [03:19<06:21,  1.9001/11/2025 11:31:47 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:48 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  28%|▎| 277/1000 [03:21<05:35,  2.1501/11/2025 11:31:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  28%|▎| 278/1000 [03:21<05:59,  2.0101/11/2025 11:31:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  28%|▎| 281/1000 [03:23<06:01,  1.9901/11/2025 11:31:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:51 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  28%|▎| 284/1000 [03:23<04:44,  2.5101/11/2025 11:31:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  28%|▎| 285/1000 [03:25<06:03,  1.9601/11/2025 11:31:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:53 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  29%|▎| 288/1000 [03:26<05:31,  2.1501/11/2025 11:31:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  29%|▎| 289/1000 [03:26<06:00,  1.9701/11/2025 11:31:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  29%|▎| 292/1000 [03:28<06:21,  1.8601/11/2025 11:31:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  30%|▎| 295/1000 [03:29<04:59,  2.3501/11/2025 11:31:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  30%|▎| 296/1000 [03:30<06:13,  1.8901/11/2025 11:31:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:31:59 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  30%|▎| 299/1000 [03:31<05:33,  2.1001/11/2025 11:32:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  30%|▎| 300/1000 [03:32<06:24,  1.8201/11/2025 11:32:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  30%|▎| 303/1000 [03:34<06:44,  1.7201/11/2025 11:32:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  31%|▎| 306/1000 [03:35<05:18,  2.1801/11/2025 11:32:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  31%|▎| 307/1000 [03:36<06:53,  1.6801/11/2025 11:32:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:05 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  31%|▎| 310/1000 [03:37<06:05,  1.8901/11/2025 11:32:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  31%|▎| 311/1000 [03:38<06:36,  1.7401/11/2025 11:32:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  31%|▎| 314/1000 [03:40<06:35,  1.7301/11/2025 11:32:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  32%|▎| 317/1000 [03:41<05:12,  2.1801/11/2025 11:32:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  32%|▎| 318/1000 [03:42<06:36,  1.7201/11/2025 11:32:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  32%|▎| 321/1000 [03:43<05:52,  1.9301/11/2025 11:32:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  32%|▎| 322/1000 [03:44<06:20,  1.7801/11/2025 11:32:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  32%|▎| 325/1000 [03:46<06:21,  1.7701/11/2025 11:32:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:14 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  33%|▎| 328/1000 [03:47<05:04,  2.2101/11/2025 11:32:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  33%|▎| 329/1000 [03:48<06:27,  1.7301/11/2025 11:32:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  33%|▎| 332/1000 [03:49<05:45,  1.9301/11/2025 11:32:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  33%|▎| 333/1000 [03:50<06:16,  1.7701/11/2025 11:32:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  34%|▎| 336/1000 [03:52<06:29,  1.7101/11/2025 11:32:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:20 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  34%|▎| 339/1000 [03:53<05:18,  2.0701/11/2025 11:32:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  34%|▎| 340/1000 [03:54<06:38,  1.6601/11/2025 11:32:22 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:23 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  34%|▎| 343/1000 [03:55<05:41,  1.9301/11/2025 11:32:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  34%|▎| 344/1000 [03:56<06:03,  1.8001/11/2025 11:32:24 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  35%|▎| 347/1000 [03:58<06:04,  1.7901/11/2025 11:32:25 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:26 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  35%|▎| 350/1000 [03:58<04:46,  2.2701/11/2025 11:32:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  35%|▎| 351/1000 [04:00<06:17,  1.7201/11/2025 11:32:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:27 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  35%|▎| 354/1000 [04:01<05:29,  1.9601/11/2025 11:32:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  36%|▎| 355/1000 [04:02<05:48,  1.8501/11/2025 11:32:29 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  36%|▎| 358/1000 [04:03<05:42,  1.8701/11/2025 11:32:31 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:32 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  36%|▎| 361/1000 [04:04<04:33,  2.3301/11/2025 11:32:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  36%|▎| 362/1000 [04:05<05:47,  1.8401/11/2025 11:32:33 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:34 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  36%|▎| 365/1000 [04:06<05:06,  2.0701/11/2025 11:32:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  37%|▎| 366/1000 [04:07<05:33,  1.9001/11/2025 11:32:35 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  37%|▎| 369/1000 [04:09<05:48,  1.8101/11/2025 11:32:36 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:37 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  37%|▎| 372/1000 [04:10<04:35,  2.2801/11/2025 11:32:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  37%|▎| 373/1000 [04:11<05:44,  1.8201/11/2025 11:32:38 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:39 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  38%|▍| 376/1000 [04:12<05:02,  2.0601/11/2025 11:32:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  38%|▍| 377/1000 [04:13<05:22,  1.9301/11/2025 11:32:40 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  38%|▍| 380/1000 [04:14<05:40,  1.8201/11/2025 11:32:42 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:43 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  38%|▍| 383/1000 [04:15<04:34,  2.2501/11/2025 11:32:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  38%|▍| 384/1000 [04:16<05:49,  1.7601/11/2025 11:32:44 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:45 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  39%|▍| 387/1000 [04:18<05:24,  1.8901/11/2025 11:32:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  39%|▍| 388/1000 [04:19<06:07,  1.6701/11/2025 11:32:46 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:48 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:48 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  39%|▍| 391/1000 [04:21<06:04,  1.6701/11/2025 11:32:48 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:49 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  39%|▍| 394/1000 [04:21<04:51,  2.0801/11/2025 11:32:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  40%|▍| 395/1000 [04:23<06:04,  1.6601/11/2025 11:32:50 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  40%|▍| 398/1000 [04:24<05:21,  1.8701/11/2025 11:32:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  40%|▍| 399/1000 [04:25<05:40,  1.7601/11/2025 11:32:52 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  40%|▍| 402/1000 [04:26<05:40,  1.7601/11/2025 11:32:54 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:55 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  40%|▍| 405/1000 [04:27<04:29,  2.2101/11/2025 11:32:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  41%|▍| 406/1000 [04:28<05:32,  1.7801/11/2025 11:32:56 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:57 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  41%|▍| 409/1000 [04:30<04:55,  2.0001/11/2025 11:32:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  41%|▍| 410/1000 [04:30<05:19,  1.8501/11/2025 11:32:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:32:58 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  41%|▍| 413/1000 [04:32<05:34,  1.7601/11/2025 11:33:00 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:01 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  42%|▍| 416/1000 [04:33<04:30,  2.1601/11/2025 11:33:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  42%|▍| 417/1000 [04:34<05:36,  1.7301/11/2025 11:33:02 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# Simulating 1000 predictions for 2024-01-23:  42%|▍| 419/1000 [04:35<06:22,  1.52
# 01/11/2025 11:33:03 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
#
# KeyboardInterrupt
#
# 01/11/2025 11:33:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:04 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:06 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:07 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:08 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:09 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:10 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:11 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:12 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:13 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:14 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:15 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# --- Logging error ---
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/logging/__init__.py", line 1163, in emit
#     stream.write(msg + self.terminator)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 662, in write
#     self._schedule_flush()
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 559, in _schedule_flush
#     self.pub_thread.schedule(_schedule_in_thread)
#   File "/opt/anaconda3/lib/python3.12/site-packages/ipykernel/iostream.py", line 266, in schedule
#     self._event_pipe.send(b"")
#   File "/opt/anaconda3/lib/python3.12/site-packages/zmq/sugar/socket.py", line 696, in send
#     return super().send(data, flags=flags, copy=copy, track=track)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "zmq/backend/cython/socket.pyx", line 742, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 783, in zmq.backend.cython.socket.Socket.send
#   File "zmq/backend/cython/socket.pyx", line 138, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
# Call stack:
#   File "/opt/anaconda3/lib/python3.12/threading.py", line 1030, in _bootstrap
#     self._bootstrap_inner()
#   File "/opt/anaconda3/lib/python3.12/threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "/opt/anaconda3/lib/python3.12/threading.py", line 1010, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/lib/python3.12/concurrent/futures/thread.py", line 92, in _worker
#     work_item.run()
#   File "/opt/anaconda3/lib/python3.12/concurrent/futures/thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/var/folders/75/krzxsmq97yn94ngdf1rt66th0000gq/T/ipykernel_1106/1757263314.py", line 49, in run_simulation
#     response = ollama.chat(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py", line 331, in chat
#     return self._request(
#   File "/opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py", line 175, in _request
#     return cls(**self._request_raw(*args, **kwargs).json())
#   File "/opt/anaconda3/lib/python3.12/site-packages/ollama/_client.py", line 116, in _request_raw
#     r = self._client.request(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 1026, in _send_single_request
#     logger.info(
# Message: 'HTTP Request: %s %s "%s %d %s"'
# Arguments: ('POST', URL('http://127.0.0.1:11434/api/chat'), 'HTTP/1.1', 200, 'OK')
# 01/11/2025 11:33:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:17 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:18 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"
# 01/11/2025 11:33:19 PM - HTTP Request: POST http://127.0.0.1:11434/api/chat "HTTP/1.1 200 OK"

# %%
predictions_df.to_csv(f'{asset_symbol}_predictions_full_no_news.csv')

# %%
rmse, r2 = plot_predictions_and_compute_metrics_probabilistic(predictions_df, asset_symbol, f"{asset_symbol}_predictions_chart_no_news.png")

# %% [markdown]
# ### Test to check if ollama is working.

# %%
response = ollama.chat(
    model="llama3.1",
    messages=[
        {"role": "system", "content": "You are a financial forecasting assistant."},
        {"role": "user", "content": "What is square of 2"}
    ]
)
response_content = response["message"]["content"]
match = re.search(r"[\$]?[0-9,]+\.?[0-9]*", response_content)
print(response_content)
if match:
    print (float(match.group().replace(",", "").replace("$", "")))

# %%
predictions_df.columns

# %%
correction_scaling = (predictions_df.iloc[:,1:].values>1000)*0.01 + (predictions_df.iloc[:,1:].values<1000)

# %%
correction_scaling

# %%
correct_values = predictions_df.iloc[:,1:].values * correction_scaling

# %%
correct_df = pd.DataFrame(data = correct_values, columns = predictions_df.columns[1:])
correct_df['Date'] = predictions_df['Date'].values

# %%
rmse, r2 = plot_predictions_and_compute_metrics_probabilistic(correct_df)

# %%
4%3
